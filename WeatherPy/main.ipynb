# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 620

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        # city_country = city_weather["country"]
        # city_date = city_weather["dt_txt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          # "Country": city_country,
                          # "Date": city_date
                          })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | harper
# Processing Record 2 of Set 1 | moss point
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | faanui
# Processing Record 6 of Set 1 | san policarpo
# Processing Record 7 of Set 1 | jasper
# Processing Record 8 of Set 1 | kruisfontein
# Processing Record 9 of Set 1 | iqaluit
# Processing Record 10 of Set 1 | port lincoln
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | beboto
# Processing Record 14 of Set 1 | novaya ladoga
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | bethanien
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | rawson
# Processing Record 20 of Set 1 | san jose de las lajas
# Processing Record 21 of Set 1 | amantea
# Processing Record 22 of Set 1 | bathsheba
# Processing Record 23 of Set 1 | betma
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | forestville
# Processing Record 26 of Set 1 | constanta
# Processing Record 27 of Set 1 | esperance
# Processing Record 28 of Set 1 | belaya gora
# Processing Record 29 of Set 1 | fort nelson
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | yarmouth
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | tura
# Processing Record 34 of Set 1 | changying
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | lorengau
# Processing Record 38 of Set 1 | coquimbo
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | coihaique
# Processing Record 41 of Set 1 | oussouye
# Processing Record 42 of Set 1 | half moon bay
# Processing Record 43 of Set 1 | clyde river
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | erithrai
# City not found. Skipping...
# Processing Record 46 of Set 1 | mackay
# Processing Record 47 of Set 1 | kavaratti
# Processing Record 48 of Set 1 | birjand
# Processing Record 49 of Set 1 | dingle
# Processing Record 50 of Set 1 | kavieng
# Processing Record 0 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 2 | ingham
# Processing Record 2 of Set 2 | nantucket
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | geraldton
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | datteln
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | altamirano
# Processing Record 9 of Set 2 | urengoy
# Processing Record 10 of Set 2 | port elizabeth
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | provideniya
# Processing Record 14 of Set 2 | aykhal
# Processing Record 15 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 2 | lazaro cardenas
# Processing Record 17 of Set 2 | saint george
# Processing Record 18 of Set 2 | malanje
# Processing Record 19 of Set 2 | san quintin
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | constitucion
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | airai
# Processing Record 24 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 2 | kulhudhuffushi
# Processing Record 26 of Set 2 | khatanga
# Processing Record 27 of Set 2 | bardiyah
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 2 | sisimiut
# Processing Record 32 of Set 2 | talikota
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | ust-koksa
# Processing Record 35 of Set 2 | burica
# City not found. Skipping...
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | guerrero negro
# Processing Record 38 of Set 2 | pevek
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | castro
# Processing Record 41 of Set 2 | foumban
# Processing Record 42 of Set 2 | la chapelle-sur-erdre
# Processing Record 43 of Set 2 | touros
# Processing Record 44 of Set 2 | ribeira grande
# Processing Record 45 of Set 2 | alyangula
# Processing Record 46 of Set 2 | cabedelo
# Processing Record 47 of Set 2 | ayan
# Processing Record 48 of Set 2 | cidreira
# Processing Record 49 of Set 2 | sibolga
# Processing Record 0 of Set 3 | batagay-alyta
# Processing Record 1 of Set 3 | san felipe
# Processing Record 2 of Set 3 | dikson
# Processing Record 3 of Set 3 | kresttsy
# Processing Record 4 of Set 3 | arkhangelsk
# Processing Record 5 of Set 3 | marsh harbour
# Processing Record 6 of Set 3 | porto nacional
# Processing Record 7 of Set 3 | khandyga
# Processing Record 8 of Set 3 | riyadh
# Processing Record 9 of Set 3 | tiksi
# Processing Record 10 of Set 3 | krasnoselkup
# Processing Record 11 of Set 3 | sokoto
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | olinda
# Processing Record 14 of Set 3 | maues
# Processing Record 15 of Set 3 | upernavik
# Processing Record 16 of Set 3 | isangel
# Processing Record 17 of Set 3 | norman wells
# Processing Record 18 of Set 3 | baykit
# Processing Record 19 of Set 3 | naron
# Processing Record 20 of Set 3 | eyl
# Processing Record 21 of Set 3 | wattegama
# Processing Record 22 of Set 3 | rikitea
# Processing Record 23 of Set 3 | bengkulu
# Processing Record 24 of Set 3 | port augusta
# Processing Record 25 of Set 3 | tasiilaq
# Processing Record 26 of Set 3 | mabay
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | chandbali
# Processing Record 29 of Set 3 | saint-philippe
# Processing Record 30 of Set 3 | lunenburg
# Processing Record 31 of Set 3 | prince rupert
# Processing Record 32 of Set 3 | barrow
# Processing Record 33 of Set 3 | kieta
# Processing Record 34 of Set 3 | hermanus
# Processing Record 35 of Set 3 | pisco
# Processing Record 36 of Set 3 | katsuura
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | simbahan
# Processing Record 39 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 3 | imperial
# Processing Record 42 of Set 3 | araouane
# Processing Record 43 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 3 | vestmannaeyjar
# Processing Record 45 of Set 3 | nerchinskiy zavod
# Processing Record 46 of Set 3 | saint-augustin
# Processing Record 47 of Set 3 | la ronge
# Processing Record 48 of Set 3 | xichang
# Processing Record 49 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 0 of Set 4 | saskylakh
# Processing Record 1 of Set 4 | sayyan
# Processing Record 2 of Set 4 | udachnyy
# Processing Record 3 of Set 4 | kabinda
# Processing Record 4 of Set 4 | romny
# Processing Record 5 of Set 4 | yellowknife
# Processing Record 6 of Set 4 | camabatela
# Processing Record 7 of Set 4 | sioux lookout
# Processing Record 8 of Set 4 | ballina
# Processing Record 9 of Set 4 | bethel
# Processing Record 10 of Set 4 | smithers
# Processing Record 11 of Set 4 | abu dhabi
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | souillac
# Processing Record 14 of Set 4 | kapaa
# Processing Record 15 of Set 4 | salamiyah
# Processing Record 16 of Set 4 | cherskiy
# Processing Record 17 of Set 4 | luban
# Processing Record 18 of Set 4 | klaksvik
# Processing Record 19 of Set 4 | chauk
# Processing Record 20 of Set 4 | sola
# Processing Record 21 of Set 4 | broome
# Processing Record 22 of Set 4 | plettenberg bay
# Processing Record 23 of Set 4 | rincon
# Processing Record 24 of Set 4 | aban
# Processing Record 25 of Set 4 | berlevag
# Processing Record 26 of Set 4 | saldanha
# Processing Record 27 of Set 4 | longyearbyen
# Processing Record 28 of Set 4 | pangnirtung
# Processing Record 29 of Set 4 | lokosovo
# Processing Record 30 of Set 4 | otukpo
# Processing Record 31 of Set 4 | say
# Processing Record 32 of Set 4 | whitefish
# Processing Record 33 of Set 4 | patharia
# Processing Record 34 of Set 4 | capoterra
# Processing Record 35 of Set 4 | heinola
# Processing Record 36 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 4 | tshela
# Processing Record 38 of Set 4 | kaeo
# Processing Record 39 of Set 4 | san cristobal
# Processing Record 40 of Set 4 | sitka
# Processing Record 41 of Set 4 | makamba
# Processing Record 42 of Set 4 | comodoro rivadavia
# Processing Record 43 of Set 4 | bajina basta
# Processing Record 44 of Set 4 | freehold
# Processing Record 45 of Set 4 | tolyatti
# Processing Record 46 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 4 | kununurra
# Processing Record 48 of Set 4 | sopot
# Processing Record 49 of Set 4 | igrim
# Processing Record 0 of Set 5 | dharchula
# Processing Record 1 of Set 5 | ouesso
# Processing Record 2 of Set 5 | nemuro
# Processing Record 3 of Set 5 | qasigiannguit
# Processing Record 4 of Set 5 | impfondo
# Processing Record 5 of Set 5 | port hardy
# Processing Record 6 of Set 5 | mishan
# Processing Record 7 of Set 5 | acapulco
# Processing Record 8 of Set 5 | san patricio
# Processing Record 9 of Set 5 | imeni poliny osipenko
# Processing Record 10 of Set 5 | severo-kurilsk
# Processing Record 11 of Set 5 | hasaki
# Processing Record 12 of Set 5 | umm lajj
# Processing Record 13 of Set 5 | guia lopes da laguna
# Processing Record 14 of Set 5 | hamilton
# Processing Record 15 of Set 5 | yumen
# Processing Record 16 of Set 5 | kodiak
# Processing Record 17 of Set 5 | guanica
# Processing Record 18 of Set 5 | nargana
# Processing Record 19 of Set 5 | cabo san lucas
# Processing Record 20 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 21 of Set 5 | leningradskiy
# Processing Record 22 of Set 5 | bandarbeyla
# Processing Record 23 of Set 5 | wajima
# Processing Record 24 of Set 5 | thompson
# Processing Record 25 of Set 5 | truro
# Processing Record 26 of Set 5 | reconquista
# Processing Record 27 of Set 5 | dorobantu
# Processing Record 28 of Set 5 | gorom-gorom
# Processing Record 29 of Set 5 | myitkyina
# Processing Record 30 of Set 5 | chuy
# Processing Record 31 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 5 | ulaanbaatar
# Processing Record 33 of Set 5 | sekoma
# Processing Record 34 of Set 5 | kushima
# Processing Record 35 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 5 | mahebourg
# Processing Record 37 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 38 of Set 5 | seydi
# Processing Record 39 of Set 5 | kahului
# Processing Record 40 of Set 5 | codrington
# Processing Record 41 of Set 5 | lasa
# Processing Record 42 of Set 5 | ilulissat
# Processing Record 43 of Set 5 | oranjemund
# Processing Record 44 of Set 5 | port hedland
# Processing Record 45 of Set 5 | tazovskiy
# Processing Record 46 of Set 5 | ponta do sol
# Processing Record 47 of Set 5 | santa cruz
# Processing Record 48 of Set 5 | rincon de la victoria
# Processing Record 49 of Set 5 | salalah
# Processing Record 0 of Set 6 | rovaniemi
# Processing Record 1 of Set 6 | bangolo
# Processing Record 2 of Set 6 | bereda
# Processing Record 3 of Set 6 | la sarre
# Processing Record 4 of Set 6 | drayton valley
# Processing Record 5 of Set 6 | haines junction
# Processing Record 6 of Set 6 | narsaq
# Processing Record 7 of Set 6 | muromtsevo
# Processing Record 8 of Set 6 | mukhen
# Processing Record 9 of Set 6 | vila franca do campo
# Processing Record 10 of Set 6 | zaraza
# Processing Record 11 of Set 6 | iracoubo
# Processing Record 12 of Set 6 | biloela
# Processing Record 13 of Set 6 | nanortalik
# Processing Record 14 of Set 6 | baoqing
# Processing Record 15 of Set 6 | eyrarbakki
# Processing Record 16 of Set 6 | portland
# Processing Record 17 of Set 6 | nikoklia
# Processing Record 18 of Set 6 | cabadiangan
# Processing Record 19 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 6 | gilgit
# Processing Record 21 of Set 6 | aguimes
# Processing Record 22 of Set 6 | sao filipe
# Processing Record 23 of Set 6 | robore
# Processing Record 24 of Set 6 | kashi
# Processing Record 25 of Set 6 | bukama
# Processing Record 26 of Set 6 | saint-pierre
# Processing Record 27 of Set 6 | arman
# Processing Record 28 of Set 6 | krasnoarmeyskiy
# Processing Record 29 of Set 6 | bilma
# Processing Record 30 of Set 6 | nouadhibou
# Processing Record 31 of Set 6 | correntina
# Processing Record 32 of Set 6 | umea
# Processing Record 33 of Set 6 | nyurba
# Processing Record 34 of Set 6 | lompoc
# Processing Record 35 of Set 6 | naze
# Processing Record 36 of Set 6 | talnakh
# Processing Record 37 of Set 6 | solnechnyy
# Processing Record 38 of Set 6 | grand-bourg
# Processing Record 39 of Set 6 | wanderlandia
# City not found. Skipping...
# Processing Record 40 of Set 6 | marienburg
# Processing Record 41 of Set 6 | chokurdakh
# Processing Record 42 of Set 6 | noumea
# Processing Record 43 of Set 6 | sahrak
# City not found. Skipping...
# Processing Record 44 of Set 6 | saint-georges
# Processing Record 45 of Set 6 | moberly
# Processing Record 46 of Set 6 | kajaani
# Processing Record 47 of Set 6 | awjilah
# Processing Record 48 of Set 6 | skelleftea
# Processing Record 49 of Set 6 | guapi
# Processing Record 0 of Set 7 | locri
# Processing Record 1 of Set 7 | alofi
# Processing Record 2 of Set 7 | ibotirama
# Processing Record 3 of Set 7 | ahipara
# Processing Record 4 of Set 7 | acarau
# Processing Record 5 of Set 7 | port hawkesbury
# Processing Record 6 of Set 7 | abong mbang
# Processing Record 7 of Set 7 | muros
# Processing Record 8 of Set 7 | wausau
# Processing Record 9 of Set 7 | mitzic
# Processing Record 10 of Set 7 | panzhihua
# Processing Record 11 of Set 7 | erenhot
# Processing Record 12 of Set 7 | sept-iles
# Processing Record 13 of Set 7 | san buenaventura
# Processing Record 14 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 7 | canton
# Processing Record 16 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 17 of Set 7 | unai
# Processing Record 18 of Set 7 | severnyy
# Processing Record 19 of Set 7 | maniitsoq
# Processing Record 20 of Set 7 | lodja
# Processing Record 21 of Set 7 | komsomolskiy
# Processing Record 22 of Set 7 | bambous virieux
# Processing Record 23 of Set 7 | fortuna
# Processing Record 24 of Set 7 | keshan
# City not found. Skipping...
# Processing Record 25 of Set 7 | ancud
# Processing Record 26 of Set 7 | susanville
# Processing Record 27 of Set 7 | ust-nera
# Processing Record 28 of Set 7 | port blair
# Processing Record 29 of Set 7 | goderich
# Processing Record 30 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 7 | ambon
# Processing Record 32 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 7 | kiruna
# Processing Record 34 of Set 7 | arauco
# Processing Record 35 of Set 7 | cadillac
# Processing Record 36 of Set 7 | abnub
# Processing Record 37 of Set 7 | dandong
# Processing Record 38 of Set 7 | ekhabi
# Processing Record 39 of Set 7 | zamora
# Processing Record 40 of Set 7 | poum
# Processing Record 41 of Set 7 | seoul
# Processing Record 42 of Set 7 | galle
# Processing Record 43 of Set 7 | muscat
# Processing Record 44 of Set 7 | jalu
# Processing Record 45 of Set 7 | khash
# Processing Record 46 of Set 7 | bloemfontein
# Processing Record 47 of Set 7 | kasempa
# Processing Record 48 of Set 7 | pokaran
# Processing Record 49 of Set 7 | karera
# Processing Record 0 of Set 8 | agboville
# Processing Record 1 of Set 8 | chapais
# Processing Record 2 of Set 8 | verkhnetulomskiy
# Processing Record 3 of Set 8 | litovko
# Processing Record 4 of Set 8 | hobyo
# Processing Record 5 of Set 8 | teahupoo
# Processing Record 6 of Set 8 | matara
# Processing Record 7 of Set 8 | puerto del rosario
# Processing Record 8 of Set 8 | beyneu
# Processing Record 9 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 10 of Set 8 | beinamar
# Processing Record 11 of Set 8 | the valley
# Processing Record 12 of Set 8 | monrovia
# Processing Record 13 of Set 8 | tuatapere
# Processing Record 14 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 8 | tezu
# Processing Record 16 of Set 8 | ponta pora
# Processing Record 17 of Set 8 | davila
# Processing Record 18 of Set 8 | moron
# Processing Record 19 of Set 8 | zhigansk
# Processing Record 20 of Set 8 | silver city
# Processing Record 21 of Set 8 | kabanjahe
# Processing Record 22 of Set 8 | new orleans
# Processing Record 23 of Set 8 | adrar
# Processing Record 24 of Set 8 | sheltozero
# Processing Record 25 of Set 8 | corinto
# Processing Record 26 of Set 8 | vardo
# Processing Record 27 of Set 8 | lavrentiya
# Processing Record 28 of Set 8 | san andres
# Processing Record 29 of Set 8 | wasilla
# Processing Record 30 of Set 8 | ostrovnoy
# Processing Record 31 of Set 8 | hirara
# Processing Record 32 of Set 8 | totness
# Processing Record 33 of Set 8 | barguzin
# Processing Record 34 of Set 8 | manokwari
# Processing Record 35 of Set 8 | eenhana
# Processing Record 36 of Set 8 | two hills
# Processing Record 37 of Set 8 | mombetsu
# Processing Record 38 of Set 8 | byron bay
# Processing Record 39 of Set 8 | corpus christi
# Processing Record 40 of Set 8 | novopokrovka
# Processing Record 41 of Set 8 | seybaplaya
# Processing Record 42 of Set 8 | aklavik
# Processing Record 43 of Set 8 | taoudenni
# Processing Record 44 of Set 8 | escarcega
# Processing Record 45 of Set 8 | egvekinot
# Processing Record 46 of Set 8 | togur
# Processing Record 47 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 8 | rotterdam
# Processing Record 49 of Set 8 | turayf
# Processing Record 0 of Set 9 | nelson bay
# Processing Record 1 of Set 9 | srednekolymsk
# Processing Record 2 of Set 9 | male
# Processing Record 3 of Set 9 | koubia
# Processing Record 4 of Set 9 | dong hoi
# Processing Record 5 of Set 9 | kirkenaer
# Processing Record 6 of Set 9 | goianapolis
# Processing Record 7 of Set 9 | vanimo
# Processing Record 8 of Set 9 | tuktoyaktuk
# Processing Record 9 of Set 9 | college
# Processing Record 10 of Set 9 | neiafu
# Processing Record 11 of Set 9 | maceio
# Processing Record 12 of Set 9 | la paz
# Processing Record 13 of Set 9 | benjamin constant
# Processing Record 14 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 15 of Set 9 | marsaxlokk
# Processing Record 16 of Set 9 | mamlyutka
# Processing Record 17 of Set 9 | mount gambier
# Processing Record 18 of Set 9 | kokkola
# Processing Record 19 of Set 9 | kupang
# Processing Record 20 of Set 9 | boyolangu
# Processing Record 21 of Set 9 | eureka
# Processing Record 22 of Set 9 | oudtshoorn
# Processing Record 23 of Set 9 | avera
# Processing Record 24 of Set 9 | kanye
# Processing Record 25 of Set 9 | svetlyy
# Processing Record 26 of Set 9 | oxford
# Processing Record 27 of Set 9 | richards bay
# Processing Record 28 of Set 9 | sobolevo
# Processing Record 29 of Set 9 | ukiah
# Processing Record 30 of Set 9 | burnie
# Processing Record 31 of Set 9 | corbelia
# Processing Record 32 of Set 9 | kabala
# Processing Record 33 of Set 9 | sao felix do xingu
# Processing Record 34 of Set 9 | matli
# Processing Record 35 of Set 9 | moerai
# Processing Record 36 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 37 of Set 9 | itumbiara
# Processing Record 38 of Set 9 | elk plain
# Processing Record 39 of Set 9 | batemans bay
# Processing Record 40 of Set 9 | tupaciguara
# Processing Record 41 of Set 9 | sur
# Processing Record 42 of Set 9 | anilao
# Processing Record 43 of Set 9 | bogorodskoye
# Processing Record 44 of Set 9 | husavik
# Processing Record 45 of Set 9 | tahta
# Processing Record 46 of Set 9 | roblin
# Processing Record 47 of Set 9 | yuzhno-kurilsk
# Processing Record 48 of Set 9 | sibut
# Processing Record 49 of Set 9 | magdagachi
# Processing Record 0 of Set 10 | havre
# Processing Record 1 of Set 10 | baghdad
# Processing Record 2 of Set 10 | madison
# Processing Record 3 of Set 10 | boa vista
# Processing Record 4 of Set 10 | lubango
# Processing Record 5 of Set 10 | havre-saint-pierre
# Processing Record 6 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 10 | barbate
# Processing Record 8 of Set 10 | am timan
# Processing Record 9 of Set 10 | sigli
# Processing Record 10 of Set 10 | puerto escondido
# Processing Record 11 of Set 10 | grindavik
# Processing Record 12 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 10 | kibre mengist
# Processing Record 14 of Set 10 | xining
# Processing Record 15 of Set 10 | ifakara
# Processing Record 16 of Set 10 | tutoia
# Processing Record 17 of Set 10 | riberalta
# Processing Record 18 of Set 10 | chengde
# Processing Record 19 of Set 10 | ilabaya
# Processing Record 20 of Set 10 | quelimane
# Processing Record 21 of Set 10 | dekoa
# City not found. Skipping...
# Processing Record 22 of Set 10 | penzance
# Processing Record 23 of Set 10 | monastyrshchina
# Processing Record 24 of Set 10 | laguna
# Processing Record 25 of Set 10 | lensk
# Processing Record 26 of Set 10 | nisia floresta
# Processing Record 27 of Set 10 | krutinka
# Processing Record 28 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 29 of Set 10 | de-kastri
# Processing Record 30 of Set 10 | maningrida
# Processing Record 31 of Set 10 | juliaca
# Processing Record 32 of Set 10 | la macarena
# Processing Record 33 of Set 10 | tessalit
# Processing Record 34 of Set 10 | blagoyevo
# Processing Record 35 of Set 10 | ibipeba
# Processing Record 36 of Set 10 | athabasca
# Processing Record 37 of Set 10 | gazojak
# Processing Record 38 of Set 10 | kutum
# Processing Record 39 of Set 10 | rocha
# Processing Record 40 of Set 10 | glendive
# Processing Record 41 of Set 10 | quatre cocos
# Processing Record 42 of Set 10 | mayumba
# Processing Record 43 of Set 10 | shimoda
# Processing Record 44 of Set 10 | jumla
# Processing Record 45 of Set 10 | evensk
# Processing Record 46 of Set 10 | sao joao da barra
# Processing Record 47 of Set 10 | gananoque
# Processing Record 48 of Set 10 | jurado
# Processing Record 49 of Set 10 | xai-xai
# Processing Record 0 of Set 11 | jaguarao
# Processing Record 1 of Set 11 | sungairaya
# Processing Record 2 of Set 11 | hendijan
# City not found. Skipping...
# Processing Record 3 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 11 | yialos
# City not found. Skipping...
# Processing Record 5 of Set 11 | yulara
# Processing Record 6 of Set 11 | iquique
# Processing Record 7 of Set 11 | ucluelet
# Processing Record 8 of Set 11 | presidencia roque saenz pena
# Processing Record 9 of Set 11 | los llanos de aridane
# Processing Record 10 of Set 11 | honavar
# Processing Record 11 of Set 11 | hanzhong
# Processing Record 12 of Set 11 | yazykovo
# Processing Record 13 of Set 11 | vila do maio
# Processing Record 14 of Set 11 | ammon
# Processing Record 15 of Set 11 | plouzane
# Processing Record 16 of Set 11 | varkaus
# Processing Record 17 of Set 11 | rio gallegos
# Processing Record 18 of Set 11 | lubao
# Processing Record 19 of Set 11 | yerbogachen
# Processing Record 20 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 21 of Set 11 | macapa
# Processing Record 22 of Set 11 | la carolina
# Processing Record 23 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 24 of Set 11 | waw
# Processing Record 25 of Set 11 | pareora
# Processing Record 26 of Set 11 | el wasta
# City not found. Skipping...
# Processing Record 27 of Set 11 | almenara
# Processing Record 28 of Set 11 | kamenka
# Processing Record 29 of Set 11 | margate
# Processing Record 30 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 31 of Set 11 | deputatskiy
# Processing Record 32 of Set 11 | vangaindrano
# Processing Record 33 of Set 11 | ligaya
# Processing Record 34 of Set 11 | lokomotivnyy
# Processing Record 35 of Set 11 | acajutla
# Processing Record 36 of Set 11 | pochutla
# Processing Record 37 of Set 11 | aksarka
# Processing Record 38 of Set 11 | juneau
# Processing Record 39 of Set 11 | vidalia
# Processing Record 40 of Set 11 | lisakovsk
# Processing Record 41 of Set 11 | mayo
# Processing Record 42 of Set 11 | saint anthony
# Processing Record 43 of Set 11 | ouadda
# Processing Record 44 of Set 11 | dujuma
# City not found. Skipping...
# Processing Record 45 of Set 11 | maunabo
# Processing Record 46 of Set 11 | emporia
# Processing Record 47 of Set 11 | houma
# Processing Record 48 of Set 11 | kathmandu
# Processing Record 49 of Set 11 | seymchan
# Processing Record 0 of Set 12 | huarmey
# Processing Record 1 of Set 12 | qaqortoq
# Processing Record 2 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 12 | praia da vitoria
# Processing Record 4 of Set 12 | kayes
# Processing Record 5 of Set 12 | masallatah
# Processing Record 6 of Set 12 | karasburg
# Processing Record 7 of Set 12 | forest grove
# Processing Record 8 of Set 12 | teplyk
# Processing Record 9 of Set 12 | labytnangi
# Processing Record 10 of Set 12 | shirokiy
# Processing Record 11 of Set 12 | mahesana
# Processing Record 12 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 13 of Set 12 | high level
# Processing Record 14 of Set 12 | krasnyy chikoy
# Processing Record 15 of Set 12 | taseyevo
# Processing Record 16 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 12 | tolaga bay
# Processing Record 18 of Set 12 | darab
# Processing Record 19 of Set 12 | mogzon
# Processing Record 20 of Set 12 | sampit
# Processing Record 21 of Set 12 | ambilobe
# Processing Record 22 of Set 12 | lulea
# Processing Record 23 of Set 12 | nome
# Processing Record 24 of Set 12 | tabialan
# City not found. Skipping...
# Processing Record 25 of Set 12 | yashkul
# Processing Record 26 of Set 12 | brae
# Processing Record 27 of Set 12 | yar-sale
# Processing Record 28 of Set 12 | cayenne
# Processing Record 29 of Set 12 | petauke
# Processing Record 30 of Set 12 | barkly west
# Processing Record 31 of Set 12 | baneh
# Processing Record 32 of Set 12 | nacozari
# Processing Record 33 of Set 12 | san carlos
# Processing Record 34 of Set 12 | moree
# Processing Record 35 of Set 12 | aktas
# Processing Record 36 of Set 12 | west fargo
# Processing Record 37 of Set 12 | nauchnyy gorodok
# Processing Record 38 of Set 12 | george
# Processing Record 39 of Set 12 | victor harbor
# Processing Record 40 of Set 12 | tymovskoye
# Processing Record 41 of Set 12 | waipawa
# Processing Record 42 of Set 12 | paamiut
# Processing Record 43 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 12 | west bay
# Processing Record 45 of Set 12 | karratha
# Processing Record 46 of Set 12 | cedar city
# Processing Record 47 of Set 12 | flinders
# Processing Record 48 of Set 12 | port keats
# Processing Record 49 of Set 12 | sinegorye
# Processing Record 0 of Set 13 | roebourne
# Processing Record 1 of Set 13 | yanam
# Processing Record 2 of Set 13 | falavarjan
# Processing Record 3 of Set 13 | svetlogorsk
# Processing Record 4 of Set 13 | roald
# Processing Record 5 of Set 13 | sidi ali
# Processing Record 6 of Set 13 | kaitangata
# Processing Record 7 of Set 13 | hofn
# Processing Record 8 of Set 13 | hami
# Processing Record 9 of Set 13 | kamwenge
# Processing Record 10 of Set 13 | payo
# Processing Record 11 of Set 13 | tsarychanka
# Processing Record 12 of Set 13 | nenjiang
# Processing Record 13 of Set 13 | skibbereen
# Processing Record 14 of Set 13 | padang
# Processing Record 15 of Set 13 | chino valley
# Processing Record 16 of Set 13 | honningsvag
# Processing Record 17 of Set 13 | namibe
# Processing Record 18 of Set 13 | lalin
# Processing Record 19 of Set 13 | manicore
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0       harper   4.3750   -7.7169     79.77        85          30        5.41
# 1   moss point  30.4116  -88.5345     76.44        44           0        9.22
# 2  east london -33.0153   27.9116     70.84        77         100        8.41
# 3    busselton -33.6500  115.3333     58.57        91           1        9.15
# 4       faanui -16.4833 -151.7500     82.94        69         100        7.78

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             harper   4.3750   -7.7169     79.77        85          30
# 1         moss point  30.4116  -88.5345     76.44        44           0
# 2        east london -33.0153   27.9116     70.84        77         100
# 3          busselton -33.6500  115.3333     58.57        91           1
# 4             faanui -16.4833 -151.7500     82.94        69         100
#
#          Wind Speed
# City_ID
# 0              5.41
# 1              9.22
# 2              8.41
# 3              9.15
# 4              7.78

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
city_data_df.plot(kind='scatter', x='Lat',y='Max Temp', marker='o', grid=True, figsize=(8,8), edgecolor='black')

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2022-10-18)")
plt.xlabel("Max Latitude")
plt.ylabel("Max Temperature (F)")


# Save the figure

# Show plot
plt.show()

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.show()

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
# plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
# plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
# plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
# plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               harper   4.3750   -7.7169     79.77        85          30
# 1           moss point  30.4116  -88.5345     76.44        44           0
# 5        san policarpo  12.1791  125.5072     80.51        72          73
# 6               jasper  37.2001  -94.3502     78.85        31           0
# 8              iqaluit  63.7506  -68.5145     11.93        57          75
#
#          Wind Speed
# City_ID
# 0              5.41
# 1              9.22
# 5              6.62
# 6             23.02
# 8             10.36

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         east london -33.0153   27.9116     70.84        77         100
# 3           busselton -33.6500  115.3333     58.57        91           1
# 4              faanui -16.4833 -151.7500     82.94        69         100
# 7        kruisfontein -34.0033   24.7314     65.88        71         100
# 9        port lincoln -34.7333  135.8667     65.03        57          61
#
#          Wind Speed
# City_ID
# 2              8.41
# 3              9.15
# 4              7.78
# 7              8.79
# 9              6.91

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Lat')
plt.ylabel('Max Temp')
plt.show()
# Out:
# The r-value is: -0.8958254897495117

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Lat')
plt.ylabel('Max Temp')
plt.show()
# Out:
# The r-value is: 0.6527605039952513

# %% [markdown]
#  **Discussion about the linear relationship:**

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Lat')
plt.ylabel('Humidity')
plt.show()
# Out:
# The r-value is: 0.291565843752105

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Lat')
plt.ylabel('Humidity')
plt.show()
# Out:
# The r-value is: 0.39157207491212553

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Lat')
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r-value is: 0.20523871426091175

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Lat')
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r-value is: 0.30465465794165614

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Lat')
plt.ylabel('Wind Speed')
plt.show()
# Out:
# The r-value is: 0.10111722066549586

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Lat')
plt.ylabel('Wind Speed')
plt.show()
# Out:
# The r-value is: -0.27022543538272054

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
